# %% [markdown]
# <a href="https://colab.research.google.com/github/allsyaa/SIC-Semesta-2026/blob/main/Handson_Sesi4_Control_Flow_If_Else.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐍 Sesi 4 — Control Flow: If-Else
# ### Hands-On Notebook · Kelas Python untuk Pemula
#
# Selamat datang di sesi ke-4! Setelah di Sesi 2 dan 3 kita belajar tentang **variabel, tipe data, `input()`,** dan **AI prompting**, sekarang saatnya membuat program kita benar-benar **"berpikir"** dan **mengambil keputusan sendiri**.
#
# ## 🎯 Tujuan Pembelajaran
# Setelah menyelesaikan notebook ini, kamu akan mampu:
# 1. Menjelaskan konsep *control flow* (alur keputusan) dalam program
# 2. Menulis pernyataan `if`, `if-else`, dan `if-elif-else`
# 3. Menggunakan operator perbandingan (`==`, `!=`, `>`, `<`, `>=`, `<=`)
# 4. Menggabungkan beberapa kondisi dengan operator logika (`and`, `or`, `not`)
# 5. Membuat kondisi bersarang (*nested condition*)
# 6. Menggabungkan `input()` dengan logika `if-else`
# 7. Membangun program klasifikasi sederhana dari nol
#
# ## 📋 Cara Menggunakan Notebook Ini
# - Jalankan setiap **code cell** secara berurutan (klik cell, lalu tekan `Shift + Enter`)
# - Setiap konsep punya bagian **📖 Penjelasan**, **💻 Contoh Kode**, dan **🧪 Coba Sendiri!**
# - Jangan skip bagian **🧪 Coba Sendiri!** — di situlah kamu benar-benar belajar
# - Di akhir notebook ada **📝 Tugas Mandiri** yang wajib dikerjakan dan dikumpulkan
#
# Yuk mulai! 🚀

# %% [markdown]
# ---
# ## 🔁 1. Kilas Balik Sesi 2
#
# Sebelum masuk ke materi baru, ingat kembali 3 hal dari Sesi 2:
#
# | Konsep | Contoh | Fungsi |
# |---|---|---|
# | **Variabel** | `nama = "Andi"` | Wadah untuk menyimpan nilai |
# | **Tipe Data** | `int`, `float`, `str`, `bool` | Jenis data yang disimpan |
# | **`input()`** | `input("Siapa nama kamu? ")` | Mengambil data dari pengguna (selalu bertipe `str`) |
#
# Ketiga hal ini adalah **bahan baku**. Hari ini kita belajar cara memakainya untuk membuat program yang **mengambil keputusan** — itulah yang disebut **control flow**.

# %%
# Contoh kilas balik: variabel, tipe data, dan input()
nama = "Andi"
umur = 17
tinggi = 165.5
sudah_daftar = True

print(nama, type(nama))
print(umur, type(umur))
print(tinggi, type(tinggi))
print(sudah_daftar, type(sudah_daftar))
# Out:
# Andi <class 'str'>
# 17 <class 'int'>
# 165.5 <class 'float'>
# True <class 'bool'>

# %% [markdown]
# ---
# ## 🚦 2. Apa Itu Control Flow?
#
# **Control flow** adalah cara program menentukan **jalur mana** yang harus dijalankan, berdasarkan suatu **kondisi**.
#
# Analogi paling gampang: **lampu lalu lintas** 🚦
# - Kalau lampu **hijau** → jalan
# - Kalau lampu **merah** → berhenti
#
# Alurnya seperti ini:
#
# ```
# MULAI
#   ↓
# Kondisi terpenuhi?
#   ↓ Ya                    ↓ Tidak
# Jalankan Jalur A         Jalankan Jalur B
#   ↓
# LANJUT KODE BERIKUTNYA
# ```
#
# Di Python, kita mengekspresikan ini dengan pernyataan **`if`**.

# %% [markdown]
# ---
# ## 🧩 3. Pernyataan `if`
#
# ### 📖 Penjelasan
# Pernyataan `if` menjalankan satu blok kode **HANYA JIKA** kondisinya bernilai `True`.
#
# ```python
# if kondisi:
#     # blok kode ini hanya jalan kalau kondisi True
#     ...
# ```
#
# **Anatomi `if`:**
# | Bagian | Contoh | Keterangan |
# |---|---|---|
# | `if` | `if` | kata kunci pembuka |
# | kondisi | `nilai > 60` | harus menghasilkan `True`/`False` |
# | `:` | `:` | titik dua, **wajib ada** |
# | indentasi | `    print(...)` | blok kode, biasanya 4 spasi |
#
# ⚠️ **Perhatian:** Python sangat memperhatikan **indentasi** (spasi di awal baris). Kalau indentasi salah, kode akan error atau berjalan tidak sesuai harapan.

# %%
# Contoh: pernyataan if
nilai = 80

if nilai > 60:
    print("Kamu lulus!")

print("Program selesai.")  # baris ini tetap jalan walau kondisi False
# Out:
# Kamu lulus!
# Program selesai.

# %%
# Contoh: pernyataan if
nilai = 80

# nilai >= 80
if nilai >= 80:
    print("Kamu lulus!")

print("Program selesai.")  # baris ini tetap jalan walau kondisi False
# Out:
# Kamu lulus!
# Program selesai.

# %% [markdown]
# ### 🧪 Coba Sendiri!
# Ubah nilai variabel `suhu` di bawah ini. Buat program yang mencetak `"Bawa payung!"` jika `suhu` lebih dari 30 (asumsikan suhu tinggi = kemungkinan hujan tropis 😄).

# %%
# TODO: lengkapi kode di bawah ini
suhu = 32  # coba ubah-ubah angka ini

# tulis pernyataan if di sini
if suhu > 30:
    print("Bawa payung!")
# Out:
# Bawa payung!

# %% [markdown]
# ---
# ## ⚖️ 4. Pernyataan `if-else`
#
# ### 📖 Penjelasan
# Bagaimana jika kita ingin program menjalankan hal **lain** saat kondisi salah? Gunakan `else`.
#
# ```python
# if kondisi:
#     # jalan jika kondisi True
#     ...
# else:
#     # jalan jika kondisi False
#     ...
# ```
#
# 🔑 **Ingat:** salah satu blok **PASTI** berjalan — tidak pernah keduanya, dan tidak pernah tidak ada.

# %%
# Contoh: if-else
suhu = 18

if suhu >= 25:
    print("Pakai kaos")
else:
    print("Pakai jaket")
# Out:
# Pakai jaket

# %% [markdown]
# ### 🧪 Coba Sendiri!
# Buat program yang mengecek variabel `nilai_ujian`. Jika nilai lebih besar atau sama dengan 60, cetak `"Lulus"`. Jika tidak, cetak `"Tidak Lulus"`.

# %%
# TODO: lengkapi kode di bawah ini
nilai_ujian = 60

if nilai_ujian >= 60:
    print("Lulus")
else:
    print("Tidak Lulus")
# Out:
# Lulus

# %% [markdown]
# ---
# ## 🪜 5. Pernyataan `if-elif-else`
#
# ### 📖 Penjelasan
# Bagaimana jika ada **lebih dari dua** kemungkinan? Gunakan `elif` (singkatan dari *"else if"*) untuk menambah cabang.
#
# ```python
# if kondisi_1:
#     ...
# elif kondisi_2:
#     ...
# elif kondisi_3:
#     ...
# else:
#     ...
# ```
#
# Python mengecek dari **atas ke bawah**, dan **berhenti** di cabang pertama yang bernilai `True`. Cabang setelahnya tidak akan dicek lagi!

# %%
# Contoh: if-elif-else untuk nilai huruf
nilai = 72

if nilai >= 90:
    print("Nilai A")
elif nilai >= 75:
    print("Nilai B")
elif nilai >= 60:
    print("Nilai C")
else:
    print("Nilai D")
# Out:
# Nilai C

# %% [markdown]
# ### 🧪 Coba Sendiri!
# Buat program kategori usia:
# - `< 13` → `"Anak-anak"`
# - `13` sampai `17` → `"Remaja"`
# - `>= 18` → `"Dewasa"`
#
# Gunakan variabel `umur` dan `if-elif-else`.

# %%
# TODO: lengkapi kode di bawah ini
umur = 15

if umur < 13:
    print("Anak-anak")
elif umur < 18:
    print("Remaja")
else:
    print("Dewasa")
# Out:
# Remaja

# %% [markdown]
# ---
# ## 🔍 6. Operator Perbandingan
#
# Setiap operator perbandingan menghasilkan `True` atau `False` — inilah yang dicek oleh `if`.
#
# | Operator | Arti | Contoh | Hasil |
# |:---:|---|---|:---:|
# | `==` | Sama dengan | `5 == 5` | `True` |
# | `!=` | Tidak sama dengan | `5 != 3` | `True` |
# | `>` | Lebih besar | `7 > 2` | `True` |
# | `<` | Lebih kecil | `2 < 7` | `True` |
# | `>=` | Lebih besar / sama dengan | `5 >= 5` | `True` |
# | `<=` | Lebih kecil / sama dengan | `4 <= 3` | `False` |
#
# ⚠️ **Jangan tertukar** antara `=` (untuk **menyimpan** nilai) dan `==` (untuk **membandingkan** nilai). Ini adalah salah satu bug paling umum bagi pemula!

# %%
# Coba jalankan dan amati hasil tiap perbandingan berikut
print("5 == 5  ->", 5 == 5)
print("5 != 3  ->", 5 != 3)
print("7 > 2   ->", 7 > 2)
print("2 < 7   ->", 2 < 7)
print("5 >= 5  ->", 5 >= 5)
print("4 <= 3  ->", 4 <= 3)
# Out:
# 5 == 5  -> True
# 5 != 3  -> True
# 7 > 2   -> True
# 2 < 7   -> True
# 5 >= 5  -> True
# 4 <= 3  -> False

# %% [markdown]
# ### 🧪 Coba Sendiri!
# Tebak dulu (di kepala/kertas) hasil dari kode berikut, baru jalankan untuk mengecek jawabanmu.

# %%
a = 12
b = 20

print(a == b)
print(a < b)
print(a >= 12)
print(b != 20)
# Out:
# False
# True
# True
# False

# %% [markdown]
# ---
# ## 🔗 7. Operator Logika (`and`, `or`, `not`)
#
# ### 📖 Penjelasan
# Operator logika memungkinkan kita menggabungkan **beberapa kondisi** sekaligus dalam satu `if`.
#
# | Operator | Arti | Contoh |
# |---|---|---|
# | `and` | Kedua kondisi harus `True` (irisan) | `umur >= 17 and punya_ktp` |
# | `or` | Salah satu kondisi cukup `True` | `hari == "Sabtu" or hari == "Minggu"` |
# | `not` | Membalik nilai `True` ↔ `False` | `not sudah_bayar` |

# %%
umur = 20
punya_ktp = False

not umur >= 17
# Out:
# False

# %%
# Contoh: operator logika
umur = 20
punya_ktp = True

if umur >= 17 and punya_ktp:
    print("Boleh memilih")
else:
    print("Belum bisa memilih")
# Out:
# Boleh memilih

# %%
# Contoh: 'or'
hari = "Sabtu"

if hari == "Sabtu" or hari == "Minggu":
    print("Yeay, akhir pekan!")
else:
    print("Masih hari kerja")
# Out:
# Yeay, akhir pekan!

# %% [markdown]
# ### 🧪 Coba Sendiri!
# Buat program penentu kelayakan mendapat diskon pelajar:
# - Syarat: `umur` di bawah 25 **DAN** `status == "pelajar"`
# - Jika memenuhi, cetak `"Dapat diskon 15%"`, jika tidak `"Tidak dapat diskon"`

# %%
# TODO: lengkapi kode di bawah ini
umur = 19
status = "pelajar"

if umur < 25 and status == "pelajar":
    print("Dapat diskon 15%")
else:
    print("Tidak dapat diskon")
# Out:
# Dapat diskon 15%

# %% [markdown]
# ---
# ## 📦 8. Kondisi Bersarang (*Nested Condition*)
#
# ### 📖 Penjelasan
# `if` di dalam `if` disebut **nested condition**. Kondisi bagian dalam hanya dicek **jika** kondisi bagian luar sudah `True`.
#
# ```python
# if kondisi_luar:
#     if kondisi_dalam:
#         ...
#     else:
#         ...
# else:
#     ...
# ```

# %%
# Contoh: nested if
umur = 25
member = True

if umur >= 18:
    if member:
        print("Diskon 20% untuk member dewasa")
    else:
        print("Dewasa, tapi belum member")
else:
    print("Belum cukup umur")
# Out:
# Diskon 20% untuk member dewasa

# %% [markdown]
# ### 🧪 Coba Sendiri!
# Buat program tiket masuk taman bermain dengan aturan:
# - Jika `umur < 3` → `"Gratis"`
# - Jika `umur >= 3`, cek lagi apakah `hari_libur` (`True`/`False`):
#   - Jika hari libur → `"Tiket Rp50.000"`
#   - Jika bukan hari libur → `"Tiket Rp35.000"`
#
# Gunakan **nested if**.

# %%
# TODO: lengkapi kode di bawah ini
umur = 15
hari_libur = True

if umur < 3:
  print("Gratis")
else:
  if hari_libur:
    print("Tiket Rp50.000")
  else:
    print("Tiket Rp35.000")
# Out:
# Tiket Rp50.000

# %% [markdown]
# ---
# ## ⌨️ 9. Menggabungkan `input()` dengan Logika
#
# ### 📖 Penjelasan
# `input()` **selalu** menghasilkan teks (`str`), meskipun pengguna mengetik angka. Untuk dibandingkan dengan angka, kita harus mengubahnya dulu dengan `int()` atau `float()`.
#
# ```python
# umur_teks = input("Masukkan umur kamu: ")
# umur = int(umur_teks)   # ⚠️ wajib diubah ke angka dulu!
#
# if umur >= 18:
#     print("Kamu sudah dewasa")
# else:
#     print("Kamu masih di bawah umur")
# ```
#
# > 💡 Di Jupyter Notebook, saat kamu menjalankan cell berisi `input()`, akan muncul kotak isian di bawah cell. Ketik jawabanmu lalu tekan Enter.

# %%
# Coba jalankan, lalu masukkan angka umur kamu saat diminta
umur_teks = input("Masukkan umur kamu: ")
umur = int(umur_teks)  # ubah ke angka dulu!

if umur >= 18:
    print("Kamu sudah dewasa")
else:
    print("Kamu masih di bawah umur")
# Out:
# Masukkan umur kamu: 13
# Kamu masih di bawah umur

# %% [markdown]
# ### 🧪 Coba Sendiri!
# Buat program yang meminta pengguna memasukkan suhu tubuh (°C) lewat `input()`, lalu:
# - Jika suhu `> 37.5` → cetak `"Demam, segera periksa ke dokter"`
# - Jika tidak → cetak `"Suhu normal"`
#
# Jangan lupa ubah hasil `input()` ke `float()`!

# %%
# TODO: lengkapi kode di bawah ini
suhu_teks = input("Masukkan suhu tubuh (derajat Celcius): ")
suhu = float(suhu_teks)

if suhu > 37.5:
  print("Demam, segera periksa ke dokter")
else:
  print("Suhu normal")
# Out:
# Masukkan suhu tubuh (derajat Celcius): 70
# Demam, segera periksa ke dokter

# %% [markdown]
# ---
# ## 🛠️ 10. Live Build: Klasifikator Nilai Ujian
#
# Sekarang kita bangun program lengkap **selangkah demi selangkah**, sama seperti saat live coding di kelas.
#
# **Tujuan program:** membaca nilai ujian (0–100) dari pengguna, lalu mencetak huruf mutu **A, B, C,** atau **D**.
#
# ### Langkah 1 — Ambil input dari pengguna

# %%
nilai = int(input("Masukkan nilai ujian (0-100): "))
print("Nilai yang dimasukkan:", nilai)
# Out:
# Masukkan nilai ujian (0-100): 80
# Nilai yang dimasukkan: 80

# %% [markdown]
# ### Langkah 2 — Tambahkan kondisi `if` pertama
# Cek dulu kemungkinan tertinggi: kalau nilai 90 ke atas, langsung beri predikat A.

# %%
nilai = int(input("Masukkan nilai ujian (0-100): "))

if nilai >= 90:
    print("Nilai A - Luar biasa!")
# Out:
# Masukkan nilai ujian (0-100): 80

# %% [markdown]
# ### Langkah 3 — Lengkapi dengan `elif` dan `else`

# %%
nilai = int(input("Masukkan nilai ujian (0-100): "))

if nilai >= 90:
    print("Nilai A - Luar biasa!")
elif nilai >= 75:
    print("Nilai B - Bagus!")
elif nilai >= 60:
    print("Nilai C - Cukup")
else:
    print("Nilai D - Perlu belajar lagi")
# Out:
# Masukkan nilai ujian (0-100): 70
# Nilai C - Cukup

# %% [markdown]
# ### ✅ Uji Coba
# Jalankan cell di atas beberapa kali dengan input berbeda (misalnya `95`, `80`, `65`, `40`) untuk memastikan semua cabang bekerja dengan benar.
#
# ### 🧪 Tantangan Tambahan
# Coba modifikasi program di atas supaya:
# 1. Menolak nilai yang di luar rentang 0–100 (cetak `"Nilai tidak valid"`)
# 2. Menambahkan predikat `"E"` untuk nilai di bawah 40

# %%
# TODO: modifikasi klasifikator nilai di sini

nilai = int(input("Masukkan nilai ujian (0-100): "))

if nilai > 100 or nilai < 0:
    print("Nilai tidak valid")
elif nilai >= 90:
    print("Nilai A - Luar biasa!")
elif nilai >= 75:
    print("Nilai B - Bagus!")
elif nilai >= 60:
    print("Nilai C - Cukup")
elif nilai >= 40:
    print("Nilai D - Perlu belajar lagi")
else:
    print("Nilai E - Tidak lulus")
# Out:
# Masukkan nilai ujian (0-100): 101
# Nilai tidak valid

# %% [markdown]
# ---
# ## 🎮 11. Mini Game: Tebak Outputnya!
#
# **Cara main:** baca kode di setiap cell, **tebak dulu** output-nya di kepala/kertas sebelum menjalankan, baru jalankan cell untuk mengecek jawabanmu!
#
# ### Soal 1

# %%
x = 10

if x > 5:
    print("Besar")
else:
    print("Kecil")

# Tebak dulu outputnya sebelum menjalankan cell ini! 🤔
# Out:
# Besar

# %% [markdown]
# ### Soal 2

# %%
umur = 16

if umur >= 17:
    print("Boleh SIM")
elif umur >= 13:
    print("Remaja")
else:
    print("Anak-anak")

# Tebak dulu outputnya sebelum menjalankan cell ini! 🤔
# Out:
# Remaja

# %% [markdown]
# ### Soal 3

# %%
a = 7
b = 7

if a == b and a > 5:
    print("Cocok & besar")
else:
    print("Tidak cocok")

# Tebak dulu outputnya sebelum menjalankan cell ini! 🤔
# Out:
# Cocok & besar

# %% [markdown]
# ---
# ## 🧠 12. Mini Kuis: Fix the Logic (Temukan & Perbaiki Bug)
#
# Setiap kode di bawah ini punya **satu kesalahan**. Baca komentar `# BUG:` untuk petunjuk, lalu perbaiki langsung di dalam cell dan jalankan sampai hasilnya benar.
#
# ### Bug 1: `=` vs `==`

# %%
nilai = 80

# BUG: tanda '=' di sini seharusnya '==' (membandingkan, bukan menyimpan nilai)
if nilai == 80:
    print("Pas!")

# Perbaiki kode di atas, lalu jalankan cell ini sampai tidak error
# Out:
# Pas!

# %% [markdown]
# ### Bug 2: Indentasi

# %%
umur = 20

if umur >= 18:
  print("Dewasa")   # BUG: baris ini harus diindentasi (masuk ke dalam blok if)

# Perbaiki indentasinya, lalu jalankan
# Out:
# Dewasa

# %% [markdown]
# ### Bug 3: Kondisi Terbalik

# %%
if int(input("nilai")) > 10:
  print("hello")
# Out:
# nilai11
# hello

# %%
suhu = 15

# BUG: logika ini terbalik -> suhu 15 itu dingin, tapi kode bilang "Panas!"
if suhu > 30:
    print("Panas!")
else:
    print("Sejuk")

# Perbaiki operator perbandingannya supaya pesannya sesuai logika
# Out:
# Sejuk

# %% [markdown]
# ---
# ## 💬 13. Diskusi: Yuk Refleksi
#
# **Pertanyaan:** *Bisakah kamu memikirkan keputusan sehari-hari yang bekerja seperti `if-elif-else`?*
#
# Contoh pemantik:
# - 🚦 Lampu lalu lintas — merah, kuning, hijau
# - 🌦️ Memilih baju berdasarkan cuaca hari ini
# - ☕ Memesan minuman — panas, dingin, atau tanpa gula?
#
# **Tulis jawabanmu di cell markdown di bawah ini** (double click untuk edit):
#
# > ✍️ if, elif, dan else ini bekerja seperti saat kita ingin memilih sebuah opsi pada hidup kita, dan pada hidup kita selalu ada pilihan yang harus kita pilih berdasarkan kondisi-kondisi tertentu, mau dari kondisi ekonomi, lingkungan, mental, ataupun fisik. Dan dari pilihan yang kita pilih, akan ada hasil/output yang kita dapat

# %% [markdown]
# ---
# ## 📌 14. Rangkuman
#
# | Konsep | Fungsi |
# |---|---|
# | `if` | Jalankan blok saat kondisi `True` |
# | `if / else` | Dua jalur, salah satu pasti berjalan |
# | `if / elif / else` | Banyak cabang, berhenti di cabang True pertama |
# | `== != > < >= <=` | Membandingkan nilai |
# | `and / or / not` | Menggabungkan / membalik kondisi |
# | Nested `if` | Kondisi di dalam kondisi |
# | `input()` + `int()`/`float()` | Ubah dulu sebelum dibandingkan dengan angka |
#
# Selamat! Program kamu sekarang bisa **berpikir sebelum bertindak**. 🎉

# %% [markdown]
# ---
# ## 📝 15. Tugas Mandiri
#
# > **Wajib dikerjakan** dan dikumpulkan sesuai instruksi dari pengajar (upload file `.ipynb` ini, atau sesuai ketentuan kelas).
#
# ### 📌 Instruksi Umum
# - Kerjakan **semua** soal di bawah ini pada cell kode yang telah disediakan (boleh menambah cell baru bila perlu)
# - Gunakan `input()` pada setiap program agar bisa diuji dengan nilai yang berbeda-beda
# - Beri **komentar** singkat pada kode untuk menjelaskan logikanya
# - Uji program kamu dengan **minimal 3 skenario input** berbeda sebelum dikumpulkan
# - Dilarang menyalin kode teman — kerjakan sesuai pemahamanmu sendiri
#
# ### ✅ Kriteria Penilaian (Rubrik)
# | Kriteria | Bobot |
# |---|---|
# | Program berjalan tanpa error | 30% |
# | Logika if-else/elif benar untuk semua kasus | 40% |
# | Kode rapi & diberi komentar | 15% |
# | Kreativitas (khusus Tugas 4 / bonus) | 15% |
#
# ---
#
# ### 🟢 Tugas 1 — Klasifikator Kategori BMI (Wajib)
# Buat program yang meminta pengguna memasukkan **berat badan (kg)** dan **tinggi badan (m)**, lalu:
# 1. Hitung BMI dengan rumus: `BMI = berat / (tinggi ** 2)`
# 2. Klasifikasikan menggunakan `if-elif-else`:
#    - `BMI < 18.5` → `"Kurus"`
#    - `18.5 <= BMI < 25` → `"Normal"`
#    - `25 <= BMI < 30` → `"Gemuk"`
#    - `BMI >= 30` → `"Obesitas"`
# 3. Cetak nilai BMI (dibulatkan 1 angka desimal) beserta kategorinya

# %%
# Tugas 1 - Klasifikator Kategori BMI
# TODO: lengkapi kode di sini
berat = float(input("Masukkan berat badan (kg): "))
tinggi = float(input("Masukkan tinggi badan (m): "))

BMI = berat / (tinggi ** 2)
# Menentukan kategori
if BMI < 18.5:
    kategori = "Kurus"
elif 18.5 <= BMI < 25:
    kategori = "Normal"
elif 25 <= BMI < 30:
    kategori = "Gemuk"
else:
    kategori = "Obesitas"

# Menampilkan hasil
print("Kategori:", kategori)
print(f"BMI Anda: {BMI:.1f}")
# Out:
# Masukkan berat badan (kg): 50
# Masukkan tinggi badan (m): 1.6
# Kategori: Normal
# BMI Anda: 19.5

# %% [markdown]
# ### 🟢 Tugas 2 — Cek Kelayakan Voting (Wajib)
# Buat program yang menanyakan **umur** dan **kewarganegaraan** (`"WNI"` atau `"WNA"`) pengguna, lalu menentukan apakah orang tersebut boleh memilih dalam pemilu, dengan syarat:
# - Umur **>= 17 tahun** **DAN** berstatus **`"WNI"`**
#
# Gunakan operator logika `and`. Cetak `"Boleh memilih"` atau `"Tidak boleh memilih"` beserta alasannya.

# %%
# Tugas 2 - Cek Kelayakan Voting
# TODO: lengkapi kode di sini
umur = int(input("Masukkan umur: "))
kewarganegaraan = input("Masukkan kewarganegaraan (WNI/WNA): ")

is_cukup_umur = umur >= 17
is_wni = kewarganegaraan == "WNI"

if is_cukup_umur and is_wni:
    print("Boleh memilih")
else:
    # kondisi jika tidak cukup umur atau bukan WNI
    if kewarganegaraan != "WNI":
        print("Tidak boleh memilih, Hanya WNI yang memiliki hak pilih.")
    else:
        print("Tidak boleh memilih, Usia Anda belum mencapai 17 tahun.")
# Out:
# Masukkan umur: 18
# Masukkan kewarganegaraan (WNI/WNA): WNA
# Tidak boleh memilih: Hanya WNI yang memiliki hak pilih.

# %% [markdown]
# ### 🟡 Tugas 3 — Sistem Tiket Bioskop dengan Diskon Bersarang (Wajib)
# Buat program tiket bioskop dengan aturan berikut (gunakan **nested if**):
# 1. Tanyakan **umur** penonton
#    - Jika `umur < 6` → `"Gratis (didampingi orang tua)"`, program selesai
#    - Jika `umur >= 6`, lanjut ke langkah 2
# 2. Tanyakan apakah hari ini **hari kerja** atau **akhir pekan** (`input()` berupa `"kerja"` / `"akhir pekan"`)
#    - Jika **hari kerja**:
#      - Jika `umur < 18` → harga `Rp20.000`
#      - Jika `umur >= 18` → harga `Rp35.000`
#    - Jika **akhir pekan**:
#      - Jika `umur < 18` → harga `Rp30.000`
#      - Jika `umur >= 18` → harga `Rp50.000`
# 3. Cetak harga tiket akhir

# %%
# Tugas 3 - Sistem Tiket Bioskop dengan Diskon Bersarang
# TODO: lengkapi kode di sini

# input umur user

umur = int(input("Masukkan umur penonton: "))

# input logic harga tiket yang didapat berdasarkan hari dan umur

if umur < 6:
    print("Gratis (didampingi orang tua)")
else:
    hari = input("Masukkan hari kerja atau akhir pekan (kerja/akhir pekan): ")
    if hari == "kerja":
        if umur < 18:
            harga = 20000
        else:
            harga = 35000
    elif hari == "akhir pekan":
        if umur < 18:
            harga = 30000
        else:
            harga = 50000
    print("harga tiket:", harga)
# Out:
# Masukkan umur penonton: 19
# Masukkan hari kerja atau akhir pekan (kerja/akhir pekan): akhir pekan
# harga tiket: 50000

# %% [markdown]
# ### 🔴 Tugas 4 — Tantangan Bonus: Kalkulator Ongkos Kirim (Opsional)
# Buat program kalkulator ongkos kirim (ongkir) sederhana dengan tema **bebas** — boleh kamu modifikasi aturannya sendiri, misalnya berdasarkan:
# - Berat paket (kg)
# - Jarak pengiriman (km) atau zona (`"dalam kota"` / `"luar kota"` / `"luar pulau"`)
# - Jenis pengiriman (`"reguler"` / `"express"`)
#
# Syarat minimal:
# - Gunakan **minimal 4 percabangan** (`if-elif-else` dan/atau nested `if`)
# - Gunakan **minimal 1 operator logika** (`and`/`or`/`not`)
# - Program harus interaktif menggunakan `input()`
#
# Ini adalah kesempatan kamu untuk berkreasi bebas — semakin realistis dan rapi logikanya, semakin baik! 🚀

# %%
# Tugas 4 (Bonus) - Kalkulator Ongkos Kirim
import math

# TODO: lengkapi kode di sini

print("=== KALKULATOR ONGKIR ===")

# ---------- Input berat ----------
try:
    berat = float(input("Berat paket (kg): "))
except ValueError:
    print("Berat harus berupa angka.")
    exit()

if berat <= 0:
    print("Berat harus lebih dari 0 kg.")
    exit()

berat_hitung = math.ceil(berat)  # pembulatan ke atas

# ---------- Input zona ----------
zona = input("Zona (dalam kota / luar kota / luar pulau): ").strip().lower()

if zona == "dalam kota":
    tarif_per_kg = 8000
elif zona == "luar kota":
    tarif_per_kg = 15000
elif zona == "luar pulau":
    tarif_per_kg = 25000
else:
    print("Zona tidak dikenali.")
    exit()

# ---------- Input jenis pengiriman ----------
jenis = input("Jenis pengiriman (reguler / express): ").strip().lower()

if jenis != "reguler" and jenis != "express":
    print("Jenis pengiriman tidak dikenali.")
    exit()

# Express tidak tersedia untuk luar pulau
if jenis == "express" and zona == "luar pulau":
    print("Maaf, layanan express tidak tersedia untuk pengiriman luar pulau.")
    exit()

# ---------- Perhitungan ----------
biaya_dasar = tarif_per_kg * berat_hitung

if jenis == "express":
    biaya_layanan = biaya_dasar * 0.5
else:
    biaya_layanan = 0

subtotal = biaya_dasar + biaya_layanan

# Diskon: berat > 10 kg DAN dalam kota
if berat_hitung > 10 and zona == "dalam kota":
    diskon = subtotal * 0.10
else:
    diskon = 0

# Asuransi: berat > 5 kg ATAU luar pulau
if berat_hitung > 5 or zona == "luar pulau":
    asuransi = 5000
else:
    asuransi = 0

total = subtotal - diskon + asuransi

# ---------- Output ----------
print("\n=== RINCIAN ONGKIR ===")
print(f"Berat dihitung   : {berat_hitung} kg (dari {berat} kg)")
print(f"Zona             : {zona}")
print(f"Jenis            : {jenis}")
print(f"Biaya dasar      : Rp {biaya_dasar:,.0f}")
if biaya_layanan > 0:
    print(f"Biaya express    : Rp {biaya_layanan:,.0f}")
if diskon > 0:
    print(f"Diskon 10%       : -Rp {diskon:,.0f}")
if asuransi > 0:
    print(f"Asuransi         : Rp {asuransi:,.0f}")
print(f"TOTAL ONGKIR     : Rp {total:,.0f}")
# Out:
# === KALKULATOR ONGKIR ===
# Berat paket (kg): 12
# Zona (dalam kota / luar kota / luar pulau): luar pulau
# Jenis pengiriman (reguler / express): reguler
#
# === RINCIAN ONGKIR ===
# Berat dihitung   : 12 kg (dari 12.0 kg)
# Zona             : luar pulau
# Jenis            : reguler
# Biaya dasar      : Rp 300,000
# Asuransi         : Rp 5,000
# TOTAL ONGKIR     : Rp 305,000

# %% [markdown]
# ---
# ## 🏁 Selesai!
#
# Kerja bagus sudah menyelesaikan hands-on Sesi 4! Simpan notebook ini (`Ctrl/Cmd + S`) dan kumpulkan sesuai instruksi pengajar.
#
# **Sesi berikutnya:** Loops — `for` & `while` 🔁
